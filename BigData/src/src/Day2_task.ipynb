# %% [markdown]
# ## 인구현황 데이터 화면출력 과제 - 201810803 장서령
# 다음 파일을 읽어서 RDD를 생성하고, 5줄을 화면출력하세요.
# pyspark 명령어와 결과출력된 노트북 ipynb 파일을 제출하세요.
# 결과가 깨져보인다면, 그 이유를 간단히 적으세요.

# %%
# %fs
ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/경기도_의정부시_인구현황_20200904.csv</td><td>경기도_의정부시_인구현황_20200904.csv</td><td>1762</td></tr><tr><td>dbfs:/FileStore/tables/제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv</td><td>제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv</td><td>532</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("dbfs:/FileStore/tables/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [FileInfo(path=&#39;dbfs:/FileStore/tables/경기도_의정부시_인구현황_20200904.csv&#39;, name=&#39;경기도_의정부시_인구현황_20200904.csv&#39;, size=1762),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv&#39;, name=&#39;제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv&#39;, size=532)]</div>

# %%
import pyspark

myConf=pyspark.SparkConf()
spark=pyspark.sql.SparkSession.builder.master("local").appName("myApp").config(conf=myConf).getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os
os.environ["PYSPARK_PYTHON"]="/usr/bin/python3"
os.environ["PYSPARK_DRIVER_PYTHON"]="/usr/bin/python3"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### 1) 경기도 의정부시 인구현황 데이터 화면 출력
# : 아래 결과를 보면 깨져나오는 부분이 있는 것을 확인할 수 있다. 깨지는 부분은 전부 한글로, utf-8 설정을 해주지 않았기 때문이라고 생각한다.

# %%
import os
dataGyeonggi=spark.sparkContext.textFile(os.path.join("/FileStore/tables/","경기도_의정부시_인구현황_20200904.csv"))
dataGyeonggi.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [&#39;�������,�α���(��),�α���(��),�α���(��),������(��),������(��),������(��),����,�����,������α�,���������,�����μ���,�μ���ȭ��ȣ,�����ͱ�������&#39;,
#  &#39;������1��       ,31467 ,16077 ,15390 ,6.89,3.52,3.37,104.46,19109 ,1.65,�����ν�,�ùκ����,031-828-2464,2020-09-04&#39;,
#  &#39;������2��       ,31440 ,15573 ,15867 ,6.88,3.41,3.47,98.15,15763 ,1.99,�����ν�,�ùκ����,031-828-2464,2020-09-04&#39;,
#  &#39;ȣ��1��         ,36282 ,17751 ,18531 ,7.95,3.89,4.06,95.79,15508 ,2.34,�����ν�,�ùκ����,031-828-2464,2020-09-04&#39;,
# ...

# %% [markdown]
# ##### 2) 제주특별자치도 서귀포시 내 연도별 65세 이상 인구수 및 고령화비율, 노령화 지수 현황 데이터 화면 출력
# : 1번의 결과와 마찬가지로, 2번 결과에서도 깨져나오는 부분이 있는 것을 확인할 수 있다. 깨지는 부분은 전부 한글로, utf-8 설정을 해주지 않았기 때문이라고 생각한다.

# %%
import os
dataJeju=spark.sparkContext.textFile(os.path.join("/FileStore/tables/","제주특별자치도_서귀포시_고령화비율및노령화지수현황_20200623.csv"))
dataJeju.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;������,�������� �α���,65���̻� �α��� ,0~14�� �α���,���ȭ����,���ȭ����,�����ͱ�������&#39;,
#  &#39;2012,154057,25826,22861,16.76,112.97,2020-06-23&#39;,
#  &#39;2013,155641,26936,22393,17.31,120.29,2020-06-23&#39;,
#  &#39;2014,158512,27877,22058,17.59,126.38,2020-06-23&#39;,
#  &#39;2015,164519,28979,22362,17.61,129.59,2020-06-23&#39;]</div>
